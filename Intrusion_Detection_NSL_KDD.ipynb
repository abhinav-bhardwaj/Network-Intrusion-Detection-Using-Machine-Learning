# %% [markdown]
# # **Data Preprocessing**

# %%
# importing required libraries
import numpy as np
import pandas as pd

import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt

# importing library for support vector machine classifier
from sklearn.svm import SVC
# importing library for K-neares-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
# importing library for Linear Discriminant Analysis Model
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# importing library for Quadratic Discriminant Analysis Model
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn import metrics
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import classification_report # for generating a classification report of model

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from keras.layers import Dense # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.models import model_from_json # saving and loading trained model

from keras.layers import LSTM
from keras.layers import Input
from keras.models import Model

# representation of model layers
from keras.utils.vis_utils import plot_model

# %%
# dataset doesn't have column names, so we have to provide it
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty_level"]

# %%
# importing dataset
data = pd.read_csv('/content/drive/MyDrive/NSL-KDD/KDDTrain+.txt',header=None, names=col_names)
#data = pd.read_csv('datasets/KDDTrain+.txt',header=None, names=col_names)

# %%
# print dataset
data
# Out:
#         duration protocol_type  ...    label difficulty_level
# 0              0           tcp  ...   normal               20
# 1              0           udp  ...   normal               15
# 2              0           tcp  ...  neptune               19
# 3              0           tcp  ...   normal               21
# 4              0           tcp  ...   normal               21
# ...          ...           ...  ...      ...              ...
# 125968         0           tcp  ...  neptune               20
# 125969         8           udp  ...   normal               21
# 125970         0           tcp  ...   normal               18
# 125971         0           tcp  ...  neptune               20
# 125972         0           tcp  ...   normal               21
#
# [125973 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty_level'],axis=1,inplace=True)
data.shape
# Out:
# (125973, 42)

# %%
# descriptive statistics of dataset
data.describe()
# Out:
#            duration  ...  dst_host_srv_rerror_rate
# count  125973.00000  ...             125973.000000
# mean      287.14465  ...                  0.120240
# std      2604.51531  ...                  0.319459
# min         0.00000  ...                  0.000000
# 25%         0.00000  ...                  0.000000
# 50%         0.00000  ...                  0.000000
# 75%         0.00000  ...                  0.000000
# max     42908.00000  ...                  1.000000
#
# [8 rows x 38 columns]

# %%
# number of attack labels 
data['label'].value_counts()
# Out:
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: label, dtype: int64

# %%
# changing attack labels to their respective attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail',
       'snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
# calling change_label() function
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# normal    67343
# Dos       45927
# Probe     11656
# R2L         995
# U2R          52
# Name: label, dtype: int64

# %% [markdown]
# # **Data Normalization**

# %%
# selecting numeric attributes columns from data
numeric_col = data.select_dtypes(include='number').columns

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
# data before normalization
data.head()
# Out:
#    duration protocol_type  ... dst_host_srv_rerror_rate   label
# 0         0           tcp  ...                     0.00  normal
# 1         0           udp  ...                     0.00  normal
# 2         0           tcp  ...                     0.00     Dos
# 3         0           tcp  ...                     0.01  normal
# 4         0           tcp  ...                     0.00  normal
#
# [5 rows x 42 columns]

# %%
# calling the normalization() function
data = normalization(data.copy(),numeric_col)

# %%
# data after normalization
data.head()
# Out:
#    duration protocol_type  ... dst_host_srv_rerror_rate   label
# 0 -0.110249           tcp  ...                -0.376387  normal
# 1 -0.110249           udp  ...                -0.376387  normal
# 2 -0.110249           tcp  ...                -0.376387     Dos
# 3 -0.110249           tcp  ...                -0.345084  normal
# 4 -0.110249           tcp  ...                -0.376387  normal
#
# [5 rows x 42 columns]

# %% [markdown]
# # **One-hot-encoding**

# %%
# selecting categorical data attributes
cat_col = ['protocol_type','service','flag']

# %%
# creating a dataframe with only categorical attributes
categorical = data[cat_col]
categorical.head()
# Out:
#   protocol_type   service flag
# 0           tcp  ftp_data   SF
# 1           udp     other   SF
# 2           tcp   private   S0
# 3           tcp      http   SF
# 4           tcp      http   SF

# %%
# one-hot-encoding categorical attributes using pandas.get_dummies() function
categorical = pd.get_dummies(categorical,columns=cat_col)
categorical.head()
# Out:
#    protocol_type_icmp  protocol_type_tcp  ...  flag_SF  flag_SH
# 0                   0                  1  ...        1        0
# 1                   0                  0  ...        1        0
# 2                   0                  1  ...        0        0
# 3                   0                  1  ...        1        0
# 4                   0                  1  ...        1        0
#
# [5 rows x 84 columns]

# %% [markdown]
# # **Binary Classification**

# %%
# changing attack labels into two categories 'normal' and 'abnormal'
bin_label = pd.DataFrame(data.label.map(lambda x:'normal' if x=='normal' else 'abnormal'))

# %%
# creating a dataframe with binary labels (normal,abnormal)
bin_data = data.copy()
bin_data['label'] = bin_label

# %%
# label encoding (0,1) binary labels (abnormal,normal)
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['intrusion'] = enc_label

# %%
np.save("labels/le1_classes.npy",le1.classes_,allow_pickle=True)

# %%
# dataset with binary labels and label encoded column
bin_data.head()
# Out:
#    duration protocol_type  ...     label intrusion
# 0 -0.110249           tcp  ...    normal         1
# 1 -0.110249           udp  ...    normal         1
# 2 -0.110249           tcp  ...  abnormal         0
# 3 -0.110249           tcp  ...    normal         1
# 4 -0.110249           tcp  ...    normal         1
#
# [5 rows x 43 columns]

# %%
# one-hot-encoding attack label
bin_data = pd.get_dummies(bin_data,columns=['label'],prefix="",prefix_sep="") 
bin_data['label'] = bin_label
bin_data
# Out:
#         duration protocol_type   service  ... abnormal  normal     label
# 0      -0.110249           tcp  ftp_data  ...        0       1    normal
# 1      -0.110249           udp     other  ...        0       1    normal
# 2      -0.110249           tcp   private  ...        1       0  abnormal
# 3      -0.110249           tcp      http  ...        0       1    normal
# 4      -0.110249           tcp      http  ...        0       1    normal
# ...          ...           ...       ...  ...      ...     ...       ...
# 125968 -0.110249           tcp   private  ...        1       0  abnormal
# 125969 -0.107178           udp   private  ...        0       1    normal
# 125970 -0.110249           tcp      smtp  ...        0       1    normal
# 125971 -0.110249           tcp    klogin  ...        1       0  abnormal
# 125972 -0.110249           tcp  ftp_data  ...        0       1    normal
#
# [125973 rows x 45 columns]

# %%
# pie chart distribution of normal and abnormal labels
plt.figure(figsize=(8,8))
plt.pie(bin_data.label.value_counts(),labels=bin_data.label.unique(),autopct='%0.2f%%')
plt.title("Pie chart distribution of normal and abnormal labels")
plt.legend()
plt.savefig('plots/Pie_chart_binary.png')
plt.show()

# %% [markdown]
# # **Multi-class Classification**

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
multi_data = data.copy()
multi_label = pd.DataFrame(multi_data.label)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le2.fit_transform)
multi_data['intrusion'] = enc_label

# %%
np.save("labels/le2_classes.npy",le2.classes_,allow_pickle=True)

# %%
# one-hot-encoding attack label
multi_data = pd.get_dummies(multi_data,columns=['label'],prefix="",prefix_sep="") 
multi_data['label'] = multi_label
multi_data
# Out:
#         duration protocol_type   service flag  ...  R2L  U2R  normal   label
# 0      -0.110249           tcp  ftp_data   SF  ...    0    0       1  normal
# 1      -0.110249           udp     other   SF  ...    0    0       1  normal
# 2      -0.110249           tcp   private   S0  ...    0    0       0     Dos
# 3      -0.110249           tcp      http   SF  ...    0    0       1  normal
# 4      -0.110249           tcp      http   SF  ...    0    0       1  normal
# ...          ...           ...       ...  ...  ...  ...  ...     ...     ...
# 125968 -0.110249           tcp   private   S0  ...    0    0       0     Dos
# 125969 -0.107178           udp   private   SF  ...    0    0       1  normal
# 125970 -0.110249           tcp      smtp   SF  ...    0    0       1  normal
# 125971 -0.110249           tcp    klogin   S0  ...    0    0       0     Dos
# 125972 -0.110249           tcp  ftp_data   SF  ...    0    0       1  normal
#
# [125973 rows x 48 columns]

# %%
# pie chart distribution of multi-class labels
plt.figure(figsize=(8,8))
plt.pie(multi_data.label.value_counts(),labels=multi_data.label.unique(),autopct='%0.2f%%')
plt.title('Pie chart distribution of multi-class labels')
plt.legend()
plt.savefig('plots/Pie_chart_multi.png')
plt.show()

# %% [markdown]
# # **Feature Extraction**

# %%
# creating a dataframe with only numeric attributes of binary class dataset and encoded label attribute 
numeric_bin = bin_data[numeric_col]
numeric_bin['intrusion'] = bin_data['intrusion']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute 
corr= numeric_bin.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)
# Out:
# count                       0.576444
# srv_serror_rate             0.648289
# serror_rate                 0.650652
# dst_host_serror_rate        0.651842
# dst_host_srv_serror_rate    0.654985
# logged_in                   0.690171
# dst_host_same_srv_rate      0.693803
# dst_host_srv_count          0.722535
# same_srv_rate               0.751913
# intrusion                   1.000000
# Name: intrusion, dtype: float64

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_bin = bin_data[['count','srv_serror_rate','serror_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
                         'logged_in','dst_host_same_srv_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_bin = numeric_bin.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
bin_data = numeric_bin.join(bin_data[['intrusion','abnormal','normal','label']])

# %%
# saving final dataset to disk
bin_data.to_csv("./datasets/bin_data.csv")
# final dataset for binary classification
bin_data
# Out:
#            count  srv_serror_rate  serror_rate  ...  abnormal  normal     label
# 0      -0.717045        -0.631929    -0.637209  ...         0       1    normal
# 1      -0.620982        -0.631929    -0.637209  ...         0       1    normal
# 2       0.339648         1.605104     1.602664  ...         1       0  abnormal
# 3      -0.690846        -0.184522    -0.189235  ...         0       1    normal
# 4      -0.472521        -0.631929    -0.637209  ...         0       1    normal
# ...          ...              ...          ...  ...       ...     ...       ...
# 125968  0.872361         1.605104     1.602664  ...         1       0  abnormal
# 125969 -0.717045        -0.631929    -0.637209  ...         0       1    normal
# 125970 -0.725778        -0.631929    -0.637209  ...         0       1    normal
# 125971  0.523041         1.605104     1.602664  ...         1       0  abnormal
# 125972 -0.725778        -0.631929    -0.637209  ...         0       1    normal
#
# [125973 rows x 97 columns]

# %%
# creating a dataframe with only numeric attributes of multi-class dataset and encoded label attribute 
numeric_multi = multi_data[numeric_col]
numeric_multi['intrusion'] = multi_data['intrusion']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute 
corr = numeric_multi.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)
# Out:
# count                       0.613251
# logged_in                   0.693770
# srv_serror_rate             0.710852
# serror_rate                 0.712861
# dst_host_serror_rate        0.714247
# dst_host_same_srv_rate      0.716820
# dst_host_srv_serror_rate    0.717387
# dst_host_srv_count          0.718579
# same_srv_rate               0.798358
# intrusion                   1.000000
# Name: intrusion, dtype: float64

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_multi = multi_data[['count','logged_in','srv_serror_rate','serror_rate','dst_host_serror_rate',
                        'dst_host_same_srv_rate','dst_host_srv_serror_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_multi = numeric_multi.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
multi_data = numeric_multi.join(multi_data[['intrusion','Dos','Probe','R2L','U2R','normal','label']])

# %%
# saving final dataset to disk
multi_data.to_csv('./datasets/multi_data.csv')

# final dataset for multi-class classification
multi_data
# Out:
#            count  logged_in  srv_serror_rate  ...  U2R  normal   label
# 0      -0.717045  -0.809262        -0.631929  ...    0       1  normal
# 1      -0.620982  -0.809262        -0.631929  ...    0       1  normal
# 2       0.339648  -0.809262         1.605104  ...    0       0     Dos
# 3      -0.690846   1.235694        -0.184522  ...    0       1  normal
# 4      -0.472521   1.235694        -0.631929  ...    0       1  normal
# ...          ...        ...              ...  ...  ...     ...     ...
# 125968  0.872361  -0.809262         1.605104  ...    0       0     Dos
# 125969 -0.717045  -0.809262        -0.631929  ...    0       1  normal
# 125970 -0.725778   1.235694        -0.631929  ...    0       1  normal
# 125971  0.523041  -0.809262         1.605104  ...    0       0     Dos
# 125972 -0.725778   1.235694        -0.631929  ...    0       1  normal
#
# [125973 rows x 100 columns]

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
# using kernel as linear 
lsvm = SVC(kernel='linear',gamma='auto') 
lsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pkl_filename = "./models/lsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = lsvm.predict(X_test) # predicting target attribute on testing dataset
ac = accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("LSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# LSVM-Classifier Binary Set-Accuracy is  96.69778370483266

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.96      0.96     14720
#       normal       0.96      0.97      0.97     16774
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.03302216295167333
# Mean Squared Error -  0.03302216295167333
# Root Mean Squared Error -  0.1817200125238641
# R2 Score -  86.74560396265441
# Accuracy -  96.69778370483266

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:500], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:500].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Linear SVM Binary Classification")
plt.savefig('plots/lsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Binary Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto') # using kernal as polynomial for quadratic svm
qsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pkl_filename = "./models/qsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk 
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=qsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("QSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# QSVM-Classifier Binary Set-Accuracy is  95.71029402425859

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.92      0.95     14720
#       normal       0.93      0.99      0.96     16774
#
#     accuracy                           0.96     31494
#    macro avg       0.96      0.95      0.96     31494
# weighted avg       0.96      0.96      0.96     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.04289705975741411
# Mean Squared Error -  0.04289705975741411
# Root Mean Squared Error -  0.20711605383797296
# R2 Score -  83.24290009836652
# Accuracy -  95.71029402425859

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Quadratic SVM Binary Classification")
plt.savefig('plots/qsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Binary Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5) # creating model for 5 neighbors
knn.fit(X_train,y_train) # training model on training dataset
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
pkl_filename = "./models/knn_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=knn.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("KNN-Classifier Binary Set-Accuracy is ", ac)
# Out:
# KNN-Classifier Binary Set-Accuracy is  98.55210516288817

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.98      0.98     14720
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.99     31494
#    macro avg       0.99      0.99      0.99     31494
# weighted avg       0.99      0.99      0.99     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.014478948371118308
# Mean Squared Error -  0.014478948371118308
# Root Mean Squared Error -  0.1203285019067316
# R2 Score -  94.18391428763977
# Accuracy -  98.55210516288817

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("KNN Binary Classification")
plt.savefig('plots/knn_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Linear Discriminant Analysis Classifier (Binary Classification)**

# %%
lda = LinearDiscriminantAnalysis() 
lda.fit(X_train, y_train)  # training model on training dataset
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
pkl_filename = "./models/lda_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lda = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = lda.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("LDA-Classifier Set-Accuracy is ", ac)
# Out:
# LDA-Classifier Set-Accuracy is  96.70730932876104

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.96      0.96     14720
#       normal       0.96      0.98      0.97     16774
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.03292690671238966
# Mean Squared Error -  0.03292690671238966
# Root Mean Squared Error -  0.1814577270671868
# R2 Score -  86.8001441639753
# Accuracy -  96.70730932876104

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Linear Discriminant Analysis Binary Classification")
plt.savefig('plots/lda_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Quadratic Discriminant Analysis Classifier (Binary Classification)**

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train) # training model on training dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
pkl_filename = "./models/qda_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qda = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = qda.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QDA-Classifier Set-Accuracy is ", ac)
# Out:
# QDA-Classifier Set-Accuracy is  68.53051374865053

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       1.00      0.33      0.49     14720
#       normal       0.63      1.00      0.77     16774
#
#     accuracy                           0.69     31494
#    macro avg       0.81      0.66      0.63     31494
# weighted avg       0.80      0.69      0.64     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.31469486251349466
# Mean Squared Error -  0.31469486251349466
# Root Mean Squared Error -  0.5609767040737919
# R2 Score -  13.222332553356363
# Accuracy -  68.53051374865053

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Quadratic Discriminant Analysis Binary Classification")
plt.savefig('plots/qda_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].values # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']].values # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # creating model

# adding input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with sigmoid activation
mlp.add(Dense(units=1,activation='sigmoid'))

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 50)                4700
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 4,751
# Trainable params: 4,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 19ms/step - loss: 0.6861 - accuracy: 0.5246 - val_loss: 0.5238 - val_accuracy: 0.9263
# Epoch 2/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4390 - accuracy: 0.9315 - val_loss: 0.3521 - val_accuracy: 0.9439
# Epoch 3/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3068 - accuracy: 0.9379 - val_loss: 0.2597 - val_accuracy: 0.9319
# Epoch 4/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2351 - accuracy: 0.9391 - val_loss: 0.2105 - val_accuracy: 0.9480
# Epoch 5/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1954 - accuracy: 0.9504 - val_loss: 0.1809 - val_accuracy: 0.9547
# Epoch 6/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1703 - accuracy: 0.9562 - val_loss: 0.1620 - val_accuracy: 0.9572
# Epoch 7/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1538 - accuracy: 0.9585 - val_loss: 0.1492 - val_accuracy: 0.9606
# Epoch 8/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1424 - accuracy: 0.9631 - val_loss: 0.1398 - val_accuracy: 0.9649
# Epoch 9/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1339 - accuracy: 0.9657 - val_loss: 0.1326 - val_accuracy: 0.9661
# Epoch 10/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1273 - accuracy: 0.9675 - val_loss: 0.1268 - val_accuracy: 0.9676
# Epoch 11/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1219 - accuracy: 0.9690 - val_loss: 0.1220 - val_accuracy: 0.9692
# Epoch 12/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1174 - accuracy: 0.9698 - val_loss: 0.1178 - val_accuracy: 0.9688
# Epoch 13/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1135 - accuracy: 0.9697 - val_loss: 0.1142 - val_accuracy: 0.9693
# Epoch 14/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1101 - accuracy: 0.9699 - val_loss: 0.1109 - val_accuracy: 0.9697
# Epoch 15/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1070 - accuracy: 0.9703 - val_loss: 0.1080 - val_accuracy: 0.9699
# Epoch 16/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1043 - accuracy: 0.9706 - val_loss: 0.1054 - val_accuracy: 0.9702
# Epoch 17/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1018 - accuracy: 0.9709 - val_loss: 0.1030 - val_accuracy: 0.9704
# Epoch 18/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0996 - accuracy: 0.9709 - val_loss: 0.1008 - val_accuracy: 0.9703
# Epoch 19/100
# 16/16 [==============================] - 0s 8ms/step - loss: 0.
100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0668 - accuracy: 0.9774 - val_loss: 0.0697 - val_accuracy: 0.9760
# Epoch 82/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0666 - accuracy: 0.9774 - val_loss: 0.0696 - val_accuracy: 0.9761
# Epoch 83/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0665 - accuracy: 0.9777 - val_loss: 0.0695 - val_accuracy: 0.9760
# Epoch 84/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0664 - accuracy: 0.9775 - val_loss: 0.0694 - val_accuracy: 0.9760
# Epoch 85/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0663 - accuracy: 0.9778 - val_loss: 0.0693 - val_accuracy: 0.9761
# Epoch 86/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0661 - accuracy: 0.9778 - val_loss: 0.0691 - val_accuracy: 0.9760
# Epoch 87/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.0690 - val_accuracy: 0.9760
# Epoch 88/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0659 - accuracy: 0.9778 - val_loss: 0.0689 - val_accuracy: 0.9760
# Epoch 89/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0657 - accuracy: 0.9780 - val_loss: 0.0688 - val_accuracy: 0.9761
# Epoch 90/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9780 - val_loss: 0.0688 - val_accuracy: 0.9761
# Epoch 91/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0655 - accuracy: 0.9780 - val_loss: 0.0686 - val_accuracy: 0.9763
# Epoch 92/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0654 - accuracy: 0.9781 - val_loss: 0.0685 - val_accuracy: 0.9761
# Epoch 93/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.0684 - val_accuracy: 0.9763
# Epoch 94/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0652 - accuracy: 0.9782 - val_loss: 0.0683 - val_accuracy: 0.9763
# Epoch 95/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0651 - accuracy: 0.9782 - val_loss: 0.0682 - val_accuracy: 0.9763
# Epoch 96/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0650 - accuracy: 0.9782 - val_loss: 0.0681 - val_accuracy: 0.9766
# Epoch 97/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0649 - accuracy: 0.9782 - val_loss: 0.0680 - val_accuracy: 0.9763
# Epoch 98/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0648 - accuracy: 0.9782 - val_loss: 0.0679 - val_accuracy: 0.9765
# Epoch 99/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9782 - val_loss: 0.0679 - val_accuracy: 0.9766
# Epoch 100/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0646 - accuracy: 0.9781 - val_loss: 0.0677 - val_accuracy: 0.9762

# %%
filepath = './models/mlp_binary.json'
weightspath = './weights/mlp_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.0659 - accuracy: 0.9778
# Test results - Loss: 0.0659344419836998 - Accuracy: 97.78053164482117

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Plot of loss vs epoch for train and test dataset')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_loss.png')
plt.show()

# %%
plot_model(mlp, to_file='plots/mlp_binary.png', show_shapes=True,)

# %%
y_pred = mlp.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/mlp_binary_roc.png')
plt.show()

# %%
pred = mlp.predict(X_test)
y_classes = (mlp.predict(X_test)>0.5).astype('int32')

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.98634791939907
# F1 Score -  0.9793127941045903
# Precision Score -  0.9723773141345872

# %% [markdown]
# # **Long Short-Term Memory Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93] # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values

# %%
y_train = np.array(y_train)

# %%
x_train = np.reshape(X_train, (X_train.shape[0],1,X_train.shape[1]))

# %%
x_train.shape
# Out:
# (94479, 1, 93)

# %%
lst = Sequential()
# input layer and LSTM layer with 50 neurons
lst.add(LSTM(50,input_dim=93))

# outpute layer with sigmoid activation
lst.add(Dense(1,activation='sigmoid'))

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# summary of model layers
lst.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (None, 50)                28800
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 28,851
# Trainable params: 28,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = lst.fit(x_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 3s 77ms/step - loss: 0.5921 - accuracy: 0.8900 - val_loss: 0.5214 - val_accuracy: 0.9159
# Epoch 2/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.4737 - accuracy: 0.9145 - val_loss: 0.4179 - val_accuracy: 0.9174
# Epoch 3/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.3811 - accuracy: 0.9150 - val_loss: 0.3385 - val_accuracy: 0.9192
# Epoch 4/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.3116 - accuracy: 0.9164 - val_loss: 0.2812 - val_accuracy: 0.9199
# Epoch 5/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.2624 - accuracy: 0.9173 - val_loss: 0.2412 - val_accuracy: 0.9205
# Epoch 6/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.2275 - accuracy: 0.9186 - val_loss: 0.2126 - val_accuracy: 0.9240
# Epoch 7/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.2020 - accuracy: 0.9310 - val_loss: 0.1913 - val_accuracy: 0.9416
# Epoch 8/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1826 - accuracy: 0.9453 - val_loss: 0.1747 - val_accuracy: 0.9510
# Epoch 9/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1671 - accuracy: 0.9535 - val_loss: 0.1613 - val_accuracy: 0.9576
# Epoch 10/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1546 - accuracy: 0.9587 - val_loss: 0.1505 - val_accuracy: 0.9605
# Epoch 11/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.1445 - accuracy: 0.9619 - val_loss: 0.1418 - val_accuracy: 0.9634
# Epoch 12/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1363 - accuracy: 0.9652 - val_loss: 0.1347 - val_accuracy: 0.9658
# Epoch 13/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1297 - accuracy: 0.9662 - val_loss: 0.1289 - val_accuracy: 0.9661
# Epoch 14/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.1243 - accuracy: 0.9668 - val_loss: 0.1241 - val_accuracy: 0.9666
# Epoch 15/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1197 - accuracy: 0.9677 - val_loss: 0.1200 - val_accuracy: 0.9677
# Epoch 16/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.1159 - accuracy: 0.9684 - val_loss: 0.1165 - val_accuracy: 0.9689
# Epoch 17/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1125 - accuracy: 0.9693 - val_loss: 0.1133 - val_accuracy: 0.9694
# Epoch 18/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1096 - accuracy: 0.9696 - val_loss: 0.1105 - val_accuracy: 0.9696
# Epoch 19/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.1069 - accuracy: 0.9699 - val_loss: 0.1080 - val_accuracy: 0.9698
# Epoch 20/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.1045 - accuracy: 0.9700 - val_loss: 0.1056 - val_accuracy: 0.9699
# Epoch 21/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.1023 - accuracy: 0.9702 - val_loss: 0.1035 - val_accuracy: 0.9698
# Epoch 22/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.1003 - accuracy: 0.9703 - val_loss: 0.1015 - val_accuracy: 0.9704
# Epoch 23/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.
100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0649 - accuracy: 0.9784 - val_loss: 0.0674 - val_accuracy: 0.9763
# Epoch 87/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0648 - accuracy: 0.9782 - val_loss: 0.0673 - val_accuracy: 0.9765
# Epoch 88/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0647 - accuracy: 0.9784 - val_loss: 0.0672 - val_accuracy: 0.9764
# Epoch 89/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0646 - accuracy: 0.9784 - val_loss: 0.0671 - val_accuracy: 0.9765
# Epoch 90/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0645 - accuracy: 0.9784 - val_loss: 0.0669 - val_accuracy: 0.9763
# Epoch 91/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0643 - accuracy: 0.9785 - val_loss: 0.0669 - val_accuracy: 0.9764
# Epoch 92/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0641 - accuracy: 0.9785 - val_loss: 0.0668 - val_accuracy: 0.9764
# Epoch 93/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.0640 - accuracy: 0.9785 - val_loss: 0.0668 - val_accuracy: 0.9765
# Epoch 94/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0639 - accuracy: 0.9786 - val_loss: 0.0666 - val_accuracy: 0.9764
# Epoch 95/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0638 - accuracy: 0.9785 - val_loss: 0.0665 - val_accuracy: 0.9763
# Epoch 96/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0637 - accuracy: 0.9786 - val_loss: 0.0664 - val_accuracy: 0.9765
# Epoch 97/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0636 - accuracy: 0.9787 - val_loss: 0.0664 - val_accuracy: 0.9765
# Epoch 98/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0634 - accuracy: 0.9787 - val_loss: 0.0662 - val_accuracy: 0.9765
# Epoch 99/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0633 - accuracy: 0.9787 - val_loss: 0.0661 - val_accuracy: 0.9764
# Epoch 100/100
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0633 - accuracy: 0.9786 - val_loss: 0.0660 - val_accuracy: 0.9765

# %%
X_test = X_test.to_numpy()

# %%
x_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
filepath = './models/lst_binary.json'
weightspath = './weights/lst_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  lst_json = lst.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(lst_json)

  # serialize weights to HDF5
  lst.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  lst = model_from_json(loaded_model_json)

  # load weights into new model
  lst.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# load json and create model
json_file = open(filepath, 'r')
loaded_model_json = json_file.read()
json_file.close()
lst = model_from_json(loaded_model_json)

# load weights into new model
lst.load_weights(weightspath)
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = lst.evaluate(x_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 2s 2ms/step - loss: 0.0646 - accuracy: 0.9777
# Test results - Loss: 0.06455659121274948 - Accuracy: 97.77100682258606%

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(lst, to_file='plots/lstm_binary.png', show_shapes=True,)

# %%
y_test.shape
# Out:
# (31494, 1)

# %%
y_pred = lst.predict(x_test)

# %%
y_pred.shape
# Out:
# (31494, 1)

# %%
y_pred = lst.predict(x_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/lstm_binary_roc.png')
plt.show()

# %%
y_classes = (lst.predict(x_test)>0.5).astype('int32')

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.9862286872540837
# F1 Score -  0.9792233929205635
# Precision Score -  0.9723169154813683

# %% [markdown]
# # **Auto Encoder Classifier (Binary Classification)**

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test = train_test_split(bin_data, test_size=0.25, random_state=42)

# %%
# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_train = X_train.drop(['intrusion','abnormal','normal','label'],axis=1) 

y_test = X_test['intrusion'] # target attribute

# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_test = X_test.drop(['intrusion','abnormal','normal','label'],axis=1)

# %%
X_train = X_train.values
X_test = X_test.values
y_test = y_test.values

# %%
input_dim = X_train.shape[1]
encoding_dim = 50

#input layer
input_layer = Input(shape=(input_dim, ))
#encoding layer with 50 neurons
encoder = Dense(encoding_dim, activation="relu")(input_layer)           
#decoding and output layer
output_layer = Dense(input_dim, activation='softmax')(encoder)

# %%
# creating model with input, encoding, decoding, output layers
autoencoder = Model(inputs=input_layer, outputs=output_layer)

# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# summary of model layers
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 93)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                4700
# _________________________________________________________________
# dense_4 (Dense)              (None, 93)                4743
# =================================================================
# Total params: 9,443
# Trainable params: 9,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = autoencoder.fit(X_train, X_train, epochs=100,batch_size=500,validation_data=(X_test, X_test)).history
# Out:
# Epoch 1/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1141 - accuracy: 0.3166 - val_loss: 0.1061 - val_accuracy: 0.4326
# Epoch 2/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1054 - accuracy: 0.5474 - val_loss: 0.1054 - val_accuracy: 0.5988
# Epoch 3/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1049 - accuracy: 0.6121 - val_loss: 0.1050 - val_accuracy: 0.6433
# Epoch 4/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1046 - accuracy: 0.6745 - val_loss: 0.1049 - val_accuracy: 0.6676
# Epoch 5/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1046 - accuracy: 0.7438 - val_loss: 0.1048 - val_accuracy: 0.7708
# Epoch 6/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1045 - accuracy: 0.7926 - val_loss: 0.1047 - val_accuracy: 0.8081
# Epoch 7/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1045 - accuracy: 0.8282 - val_loss: 0.1047 - val_accuracy: 0.8513
# Epoch 8/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1045 - accuracy: 0.8468 - val_loss: 0.1047 - val_accuracy: 0.8534
# Epoch 9/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8560 - val_loss: 0.1047 - val_accuracy: 0.8552
# Epoch 10/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8609 - val_loss: 0.1047 - val_accuracy: 0.8397
# Epoch 11/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8623 - val_loss: 0.1047 - val_accuracy: 0.8487
# Epoch 12/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8625 - val_loss: 0.1046 - val_accuracy: 0.8476
# Epoch 13/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8606 - val_loss: 0.1046 - val_accuracy: 0.8348
# Epoch 14/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8604 - val_loss: 0.1046 - val_accuracy: 0.8692
# Epoch 15/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8605 - val_loss: 0.1046 - val_accuracy: 0.8806
# Epoch 16/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8599 - val_loss: 0.1046 - val_accuracy: 0.8703
# Epoch 17/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8610 - val_loss: 0.1046 - val_accuracy: 0.8633
# Epoch 18/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8581 - val_loss: 0.1046 - val_accuracy: 0.8394
# Epoch 19/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8624 - val_loss: 0.1046 - val_accuracy: 0.8694
# Epoch 20/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8624 - val_loss: 0.1046 - val_accuracy: 0.8574
# Epoch 21/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8644 - val_loss: 0.1046 - val_accuracy: 0.8253
# Epoch 22/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8620 - val_loss: 0.1046 - val_accuracy: 0.8977
# Epoch 23/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8657 - val_loss: 0.1046 - val_accuracy: 0.8573
# Epoch 24/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.8692 - val_loss: 0.1046 - val_accuracy: 0.9079
# Epoch 25/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8699 - val_loss: 0.1046 - val_accuracy: 0.8844
# Epoch 26/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8734 - val_loss: 0.1046 - val_accuracy: 0.9050
# Epoch 27/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8813 - val_loss: 0.1046 - val_accuracy: 0.8933
# Epoch 28/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.8799 - val_loss: 0.1046 - val_accuracy: 0.8745
# Epoch 29/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.8808 - val_loss: 0.1046 - val_accuracy: 0.8985
# Epoch 30/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8797 - val_loss: 0.1046 - val_accuracy: 0.8897
# Epoch 31/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8853 - val_loss: 0.1046 - val_accuracy: 0.8956
# Epoch 32/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.8865 - val_loss: 0.1046 - val_accuracy: 0.9200
# Epoch 33/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8889 - val_loss: 0.1046 - val_accuracy: 0.8885
# Epoch 34/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8904 - val_loss: 0.1046 - val_accuracy: 0.8879
# Epoch 35/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8931 - val_loss: 0.1046 - val_accuracy: 0.8768
# Epoch 36/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8943 - val_loss: 0.1046 - val_accuracy: 0.8840
# Epoch 37/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8959 - val_loss: 0.1046 - val_accuracy: 0.9070
# Epoch 38/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.8977 - val_loss: 0.1046 - val_accuracy: 0.9149
# Epoch 39/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9010 - val_loss: 0.1046 - val_accuracy: 0.9198
# Epoch 40/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9020 - val_loss: 0.1046 - val_accuracy: 0.8953
# Epoch 41/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9021 - val_loss: 0.1046 - val_accuracy: 0.8782
# Epoch 42/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9028 - val_loss: 0.1046 - val_accuracy: 0.8938
# Epoch 43/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9045 - val_loss: 0.1046 - val_accuracy: 0.9109
# Epoch 44/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9050 - val_loss: 0.1046 - val_accuracy: 0.8990
# Epoch 45/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9064 - val_loss: 0.1046 - val_accuracy: 0.9380
# Epoch 46/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9065 - val_loss: 0.1046 - val_accuracy: 0.9100
# Epoch 47/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9067 - val_loss: 0.1046 - val_accuracy: 0.9045
# Epoch 48/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9076 - val_loss: 0.1046 - val_accuracy: 0.9112
# Epoch 49/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9084 - val_loss: 0.1046 - val_accuracy: 0.9077
# Epoch 50/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9079 - val_loss: 0.1046 - val_accuracy: 0.9092
# Epoch 51/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9083 - val_loss: 0.1046 - val_accuracy: 0.8964
# Epoch 52/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9096 - val_loss: 0.1046 - val_accuracy: 0.9009
# Epoch 53/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9083 - val_loss: 0.1046 - val_accuracy: 0.9131
# Epoch 54/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9095 - val_loss: 0.1046 - val_accuracy: 0.8896
# Epoch 55/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9091 - val_loss: 0.1046 - val_accuracy: 0.9410
# Epoch 56/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9068 - val_loss: 0.1046 - val_accuracy: 0.9089
# Epoch 57/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9080 - val_loss: 0.1046 - val_accuracy: 0.8875
# Epoch 58/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9083 - val_loss: 0.1046 - val_accuracy: 0.9200
# Epoch 59/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9083 - val_loss: 0.1046 - val_accuracy: 0.8995
# Epoch 60/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9088 - val_loss: 0.1046 - val_accuracy: 0.8858
# Epoch 61/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9090 - val_loss: 0.1046 - val_accuracy: 0.8868
# Epoch 62/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9086 - val_loss: 0.1046 - val_accuracy: 0.9175
# Epoch 63/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9090 - val_loss: 0.1046 - val_accuracy: 0.9404
# Epoch 64/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9085 - val_loss: 0.1046 - val_accuracy: 0.9321
# Epoch 65/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9104 - val_loss: 0.1046 - val_accuracy: 0.9000
# Epoch 66/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9098 - val_loss: 0.1046 - val_accuracy: 0.8993
# Epoch 67/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9105 - val_loss: 0.1046 - val_accuracy: 0.8655
# Epoch 68/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9096 - val_loss: 0.1046 - val_accuracy: 0.9052
# Epoch 69/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9099 - val_loss: 0.1046 - val_accuracy: 0.9354
# Epoch 70/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9109 - val_loss: 0.1046 - val_accuracy: 0.9064
# Epoch 71/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9095 - val_loss: 0.1046 - val_accuracy: 0.8942
# Epoch 72/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9118 - val_loss: 0.1046 - val_accuracy: 0.9147
# Epoch 73/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9125 - val_loss: 0.1046 - val_accuracy: 0.9146
# Epoch 74/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9119 - val_loss: 0.1046 - val_accuracy: 0.8799
# Epoch 75/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9113 - val_loss: 0.1046 - val_accuracy: 0.9048
# Epoch 76/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9119 - val_loss: 0.1046 - val_accuracy: 0.9141
# Epoch 77/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9120 - val_loss: 0.1046 - val_accuracy: 0.8904
# Epoch 78/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9122 - val_loss: 0.1046 - val_accuracy: 0.9590
# Epoch 79/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9124 - val_loss: 0.1046 - val_accuracy: 0.9375
# Epoch 80/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9123 - val_loss: 0.1046 - val_accuracy: 0.8954
# Epoch 81/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9124 - val_loss: 0.1046 - val_accuracy: 0.9167
# Epoch 82/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9123 - val_loss: 0.1046 - val_accuracy: 0.9242
# Epoch 83/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9133 - val_loss: 0.1046 - val_accuracy: 0.9253
# Epoch 84/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9141 - val_loss: 0.1046 - val_accuracy: 0.9006
# Epoch 85/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9125 - val_loss: 0.1046 - val_accuracy: 0.8932
# Epoch 86/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9128 - val_loss: 0.1046 - val_accuracy: 0.9258
# Epoch 87/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9130 - val_loss: 0.1046 - val_accuracy: 0.9204
# Epoch 88/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9133 - val_loss: 0.1046 - val_accuracy: 0.9536
# Epoch 89/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9131 - val_loss: 0.1046 - val_accuracy: 0.9110
# Epoch 90/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9135 - val_loss: 0.1046 - val_accuracy: 0.9309
# Epoch 91/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9135 - val_loss: 0.1046 - val_accuracy: 0.9114
# Epoch 92/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9127 - val_loss: 0.1046 - val_accuracy: 0.8951
# Epoch 93/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9122 - val_loss: 0.1046 - val_accuracy: 0.9329
# Epoch 94/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9127 - val_loss: 0.1046 - val_accuracy: 0.9319
# Epoch 95/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9141 - val_loss: 0.1046 - val_accuracy: 0.9486
# Epoch 96/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9143 - val_loss: 0.1046 - val_accuracy: 0.8926
# Epoch 97/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9140 - val_loss: 0.1046 - val_accuracy: 0.9072
# Epoch 98/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1043 - accuracy: 0.9140 - val_loss: 0.1046 - val_accuracy: 0.8950
# Epoch 99/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9135 - val_loss: 0.1046 - val_accuracy: 0.9093
# Epoch 100/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9140 - val_loss: 0.1046 - val_accuracy: 0.8932

# %%
filepath = './models/ae_binary.json'
weightspath = './weights/ae_binary.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  autoencoder_json = autoencoder.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(autoencoder_json)

  # serialize weights to HDF5
  autoencoder.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  autoencoder = model_from_json(loaded_model_json)

  # load weights into new model
  autoencoder.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = autoencoder.evaluate(X_test, X_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.1046 - accuracy: 0.8932
# Test results - Loss: 0.10457377135753632 - Accuracy: 0.89324951171875%

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_binary_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_binary_accuracy.png')
plt.show()

# %%
# representation of model layers
plot_model(autoencoder, to_file='plots/ae_binary.png', show_shapes=True,)

# %%
# calculating reconstruction error 
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          31494.000000  31494.000000
# mean               0.104574      0.532609
# std                0.043578      0.498943
# min                0.040634      0.000000
# 25%                0.074498      0.000000
# 50%                0.083821      1.000000
# 75%                0.151404      1.000000
# max                0.229788      1.000000

# %%
predictions.shape
# Out:
# (31494, 93)

# %% [markdown]
# ## **AE Classifier**

# %%
i_dim = predictions.shape[1]

#input layer
i_layer = Input(shape=(i_dim, ))
#hidden layer with 50 neurons
fvector = Dense(50, activation="sigmoid")(i_layer)                    
#doutput layer
o_layer = Dense(1, activation='sigmoid')(fvector)

# %%
# creating model with input, encoding, decoding, output layers
ae_classifier = Model(inputs=i_layer, outputs=o_layer)

# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
# summary of model layers
ae_classifier.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 93)]              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                4700
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 4,751
# Trainable params: 4,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
his = ae_classifier.fit(predictions, y_test, epochs=300,batch_size=500, validation_split=0.2).history
# Out:
# Epoch 1/300
# 51/51 [==============================] - 1s 5ms/step - loss: 0.8103 - accuracy: 0.4673 - val_loss: 0.6800 - val_accuracy: 0.4679
# Epoch 2/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6482 - accuracy: 0.7674 - val_loss: 0.6264 - val_accuracy: 0.8559
# Epoch 3/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6103 - accuracy: 0.8559 - val_loss: 0.5928 - val_accuracy: 0.8730
# Epoch 4/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.8855 - val_loss: 0.5582 - val_accuracy: 0.8846
# Epoch 5/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5412 - accuracy: 0.8856 - val_loss: 0.5216 - val_accuracy: 0.8839
# Epoch 6/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5039 - accuracy: 0.8849 - val_loss: 0.4834 - val_accuracy: 0.8838
# Epoch 7/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.8844 - val_loss: 0.4450 - val_accuracy: 0.8841
# Epoch 8/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.4281 - accuracy: 0.8904 - val_loss: 0.4086 - val_accuracy: 0.8998
# Epoch 9/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.3934 - accuracy: 0.8985 - val_loss: 0.3756 - val_accuracy: 0.9009
# Epoch 10/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.3629 - accuracy: 0.8990 - val_loss: 0.3474 - val_accuracy: 0.9017
# Epoch 11/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.3371 - accuracy: 0.8993 - val_loss: 0.3242 - val_accuracy: 0.9020
# Epoch 12/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.3159 - accuracy: 0.9001 - val_loss: 0.3050 - val_accuracy: 0.9040
# Epoch 13/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2987 - accuracy: 0.9011 - val_loss: 0.2894 - val_accuracy: 0.9052
# Epoch 14/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.9012 - val_loss: 0.2768 - val_accuracy: 0.9052
# Epoch 15/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.9013 - val_loss: 0.2661 - val_accuracy: 0.9054
# Epoch 16/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2635 - accuracy: 0.9014 - val_loss: 0.2574 - val_accuracy: 0.9055
# Epoch 17/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2555 - accuracy: 0.9016 - val_loss: 0.2500 - val_accuracy: 0.9054
# Epoch 18/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2487 - accuracy: 0.9016 - val_loss: 0.2439 - val_accuracy: 0.9054
# Epoch 19/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2430 - accuracy: 0.9043 - val_loss: 0.2387 - val_accuracy: 0.9235
# Epoch 20/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2382 - accuracy: 0.9205 - val_loss: 0.2339 - val_accuracy: 0.9305
# Epoch 21/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2342 - accuracy: 0.9252 - val_loss: 0.2301 - val_accuracy: 0.9230
# Epoch 22/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2307 - accuracy: 0.9195 - val_loss: 0.2269 - val_accuracy: 0.9211
# Epoch 23/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2279 - accuracy: 0.9195 - val_loss: 0.2244 - val_accuracy: 0.9111
# Epoch 24/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2254 - accuracy: 0.9176 - val_loss: 0.2220 - val_accuracy: 0.9108
# Epoch 25/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2234 - accuracy: 0.9154 - val_loss: 0.2201 - val_accuracy: 0.9082
# Epoch 26/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2215 - accuracy: 0.9150 - val_loss: 0.2183 - val_accuracy: 0.9103
# Epoch 27/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2200 - accuracy: 0.9122 - val_loss: 0.2166 - val_accuracy: 0.9124
# Epoch 28/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9131 - val_loss: 0.2154 - val_accuracy: 0.9081
# Epoch 29/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2175 - accuracy: 0.9121 - val_loss: 0.2140 - val_accuracy: 0.9157
# Epoch 30/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2164 - accuracy: 0.9177 - val_loss: 0.2129 - val_accuracy: 0.9182
# Epoch 31/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2153 - accuracy: 0.9155 - val_loss: 0.2122 - val_accuracy: 0.9111
# Epoch 32/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2145 - accuracy: 0.9151 - val_loss: 0.2111 - val_accuracy: 0.9200
# Epoch 33/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2136 - accuracy: 0.9181 - val_loss: 0.2105 - val_accuracy: 0.9133
# Epoch 34/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9188 - val_loss: 0.2096 - val_accuracy: 0.9167
# Epoch 35/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2121 - accuracy: 0.9202 - val_loss: 0.2089 - val_accuracy: 0.9186
# Epoch 36/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2115 - accuracy: 0.9212 - val_loss: 0.2083 - val_accuracy: 0.9187
# Epoch 37/300
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2108 - accuracy: 0.9210 - val_loss: 0.2074 - val_accuracy: 0.9221
# Epoch 38/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.9216 - val_loss: 0.2068 - val_accuracy: 0.9221
# Epoch 39/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 0.9220 - val_loss: 0.2061 - val_accuracy: 0.9222
# Epoch 40/300
# 51/51 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9224 - val_loss: 0.2059 - val_accuracy: 0.9214
# Epoch 41/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2087 - accuracy: 0.9227 - val_loss: 0.2051 - val_accuracy: 0.9224
# Epoch 42/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2081 - accuracy: 0.9223 - val_loss: 0.2045 - val_accuracy: 0.9225
# Epoch 43/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2076 - accuracy: 0.9228 - val_loss: 0.2039 - val_accuracy: 0.9228
# Epoch 44/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2072 - accuracy: 0.9229 - val_loss: 0.2038 - val_accuracy: 0.9219
# Epoch 45/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2068 - accuracy: 0.9226 - val_loss: 0.2032 - val_accuracy: 0.9221
# Epoch 46/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.9226 - val_loss: 0.2025 - val_accuracy: 0.9228
# Epoch 47/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.9229 - val_loss: 0.2020 - val_accuracy: 0.9228
# Epoch 48/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2055 - accuracy: 0.9228 - val_loss: 0.2016 - val_accuracy: 0.9227
# Epoch 49/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2050 - accuracy: 0.9235 - val_loss: 0.2020 - val_accuracy: 0.9224
# Epoch 50/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2050 - accuracy: 0.9233 - val_loss: 0.2011 - val_accuracy: 0.9238
# Epoch 51/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2044 - accuracy: 0.9233 - val_loss: 0.2004 - val_accuracy: 0.9246
# Epoch 52/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2041 - accuracy: 0.9234 - val_loss: 0.2001 - val_accuracy: 0.9244
# Epoch 53/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2037 - accuracy: 0.9236 - val_loss: 0.1998 - val_accuracy: 0.9243
# Epoch 54/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.2034 - accuracy: 0.
300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1969 - accuracy: 0.9269 - val_loss: 0.1918 - val_accuracy: 0.9295
# Epoch 91/300
# 51/51 [==============================] - 0s 2ms/step - loss: 0.1969 - accuracy: 0.9268 - val_loss: 0.1916 - val_accuracy: 0.9300
# Epoch 92/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1967 - accuracy: 0.9272 - val_loss: 0.1913 - val_accuracy: 0.9303
# Epoch 93/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9268 - val_loss: 0.1909 - val_accuracy: 0.9309
# Epoch 94/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9270 - val_loss: 0.1910 - val_accuracy: 0.9306
# Epoch 95/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9272 - val_loss: 0.1907 - val_accuracy: 0.9305
# Epoch 96/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9270 - val_loss: 0.1908 - val_accuracy: 0.9306
# Epoch 97/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1963 - accuracy: 0.9272 - val_loss: 0.1907 - val_accuracy: 0.9306
# Epoch 98/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1962 - accuracy: 0.9271 - val_loss: 0.1904 - val_accuracy: 0.9306
# Epoch 99/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1961 - accuracy: 0.9273 - val_loss: 0.1903 - val_accuracy: 0.9306
# Epoch 100/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.9273 - val_loss: 0.1906 - val_accuracy: 0.9303
# Epoch 101/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9270 - val_loss: 0.1900 - val_accuracy: 0.9311
# Epoch 102/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.9274 - val_loss: 0.1900 - val_accuracy: 0.9308
# Epoch 103/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9273 - val_loss: 0.1899 - val_accuracy: 0.9308
# Epoch 104/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9273 - val_loss: 0.1901 - val_accuracy: 0.9306
# Epoch 105/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9275 - val_loss: 0.1899 - val_accuracy: 0.9306
# Epoch 106/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9274 - val_loss: 0.1899 - val_accuracy: 0.9308
# Epoch 107/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9275 - val_loss: 0.1898 - val_accuracy: 0.9308
# Epoch 108/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9278 - val_loss: 0.1904 - val_accuracy: 0.9300
# Epoch 109/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9278 - val_loss: 0.1900 - val_accuracy: 0.9305
# Epoch 110/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.9276 - val_loss: 0.1896 - val_accuracy: 0.9314
# Epoch 111/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.9278 - val_loss: 0.1897 - val_accuracy: 0.9314
# Epoch 112/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9279 - val_loss: 0.1895 - val_accuracy: 0.9316
# Epoch 113/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9280 - val_loss: 0.1900 - val_accuracy: 0.9308
# Epoch 114/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9279 - val_loss: 0.1895 - val_accuracy: 0.9316
# Epoch 115/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9279 - val_loss: 0.1892 - val_accuracy: 0.9319
# Epoch 116/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9280 - val_loss: 0.1894 - val_accuracy: 0.9316
# Epoch 117/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1952 - accuracy: 0.9285 - val_loss: 0.1893 - val_accuracy: 0.9317
# Epoch 118/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9285 - val_loss: 0.1897 - val_accuracy: 0.9309
# Epoch 119/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9282 - val_loss: 0.1892 - val_accuracy: 0.9322
# Epoch 120/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1952 - accuracy: 0.9286 - val_loss: 0.1890 - val_accuracy: 0.9325
# Epoch 121/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9289 - val_loss: 0.1894 - val_accuracy: 0.9314
# Epoch 122/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9291 - val_loss: 0.1902 - val_accuracy: 0.9305
# Epoch 123/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1952 - accuracy: 0.9286 - val_loss: 0.1892 - val_accuracy: 0.9321
# Epoch 124/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9291 - val_loss: 0.1894 - val_accuracy: 0.9313
# Epoch 125/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9288 - val_loss: 0.1894 - val_accuracy: 0.9314
# Epoch 126/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.9288 - val_loss: 0.1888 - val_accuracy: 0.9325
# Epoch 127/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.
300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1841 - accuracy: 0.9316 - val_loss: 0.1768 - val_accuracy: 0.9343
# Epoch 279/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9318 - val_loss: 0.1764 - val_accuracy: 0.9352
# Epoch 280/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1838 - accuracy: 0.9319 - val_loss: 0.1762 - val_accuracy: 0.9351
# Epoch 281/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1836 - accuracy: 0.9318 - val_loss: 0.1760 - val_accuracy: 0.9352
# Epoch 282/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.9321 - val_loss: 0.1760 - val_accuracy: 0.9348
# Epoch 283/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1834 - accuracy: 0.9320 - val_loss: 0.1762 - val_accuracy: 0.9341
# Epoch 284/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1831 - accuracy: 0.9319 - val_loss: 0.1755 - val_accuracy: 0.9351
# Epoch 285/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1830 - accuracy: 0.9319 - val_loss: 0.1755 - val_accuracy: 0.9368
# Epoch 286/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9323 - val_loss: 0.1753 - val_accuracy: 0.9348
# Epoch 287/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1826 - accuracy: 0.9320 - val_loss: 0.1752 - val_accuracy: 0.9348
# Epoch 288/300
# 51/51 [==============================] - 0s 4ms/step - loss: 0.1824 - accuracy: 0.9322 - val_loss: 0.1749 - val_accuracy: 0.9348
# Epoch 289/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9320 - val_loss: 0.1748 - val_accuracy: 0.9348
# Epoch 290/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1820 - accuracy: 0.9322 - val_loss: 0.1743 - val_accuracy: 0.9357
# Epoch 291/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9326 - val_loss: 0.1743 - val_accuracy: 0.9349
# Epoch 292/300
# 51/51 [==============================] - 0s 4ms/step - loss: 0.1818 - accuracy: 0.9322 - val_loss: 0.1740 - val_accuracy: 0.9352
# Epoch 293/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9324 - val_loss: 0.1738 - val_accuracy: 0.9359
# Epoch 294/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1815 - accuracy: 0.9326 - val_loss: 0.1736 - val_accuracy: 0.9355
# Epoch 295/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1812 - accuracy: 0.9322 - val_loss: 0.1734 - val_accuracy: 0.9354
# Epoch 296/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9326 - val_loss: 0.1732 - val_accuracy: 0.9360
# Epoch 297/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1809 - accuracy: 0.9325 - val_loss: 0.1730 - val_accuracy: 0.9359
# Epoch 298/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1809 - accuracy: 0.9328 - val_loss: 0.1729 - val_accuracy: 0.9355
# Epoch 299/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9326 - val_loss: 0.1728 - val_accuracy: 0.9352
# Epoch 300/300
# 51/51 [==============================] - 0s 3ms/step - loss: 0.1804 - accuracy: 0.9326 - val_loss: 0.1732 - val_accuracy: 0.9346

# %%
filepath = './models/ae_classifier_binary.json'
weightspath = './weights/ae_classifier_binary.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  ae_classifier_json = ae_classifier.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(ae_classifier_json)

  # serialize weights to HDF5
  ae_classifier.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  ae_classifier = model_from_json(loaded_model_json)

  # load weights into new model
  ae_classifier.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
ae_classifier.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = ae_classifier.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.7546 - accuracy: 0.8263
# Test results - Loss: 0.7546330690383911 - Accuracy: 82.62843489646912%

# %%
# representation of model layers
plot_model(ae_classifier, to_file='plots/ae_classifier_binary.png', show_shapes=True)

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(his['loss'])
plt.plot(his['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_classifier_binary_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(his['accuracy'])
plt.plot(his['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_classifier_binary_accuracy.png')
plt.show()

# %%
y_pred = ae_classifier.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
#auc = auc(fpr, tpr)

# %%
plt.plot([0, 1], [0, 1], 'k--')
#plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.plot(fpr, tpr)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/ae_binary_roc.png')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
pred = ae_classifier.predict(X_test)
y_classes = (ae_classifier.predict(X_test)>0.5).astype('int32')

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.9784785978299749
# F1 Score -  0.8571428571428572
# Precision Score -  0.7625795660456256

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded, original)
Y = multi_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
lsvm=SVC(kernel='linear',gamma='auto')
lsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# saving trained model to disk
pkl_filename = "./models/lsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loade model from disk")
# Out:
# Saved model to disk
# Loade model from disk

# %%
y_pred=lsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("LSVM-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# LSVM-Classifier Multi-class Set-Accuracy is  95.24671365974471

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.95      0.96      0.96     11484
#        Probe       0.86      0.79      0.82      2947
#          R2L       0.61      0.60      0.60       274
#          U2R       0.00      0.00      0.00        15
#       normal       0.97      0.98      0.98     16774
#
#     accuracy                           0.95     31494
#    macro avg       0.68      0.67      0.67     31494
# weighted avg       0.95      0.95      0.95     31494
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.10132088651806694
# Mean Squared Error -  0.28332380770940496
# Root Mean Squared Error -  0.5322816995815326
# R2 Score -  92.18330960765653
# Accuracy -  95.24671365974471

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Linear SVM Multi-class Classification")
plt.savefig('plots/lsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Multi-class Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto')
qsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pkl_filename = "./models/qsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=qsvm.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QSVM-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# QSVM-Classifier Multi-class Set-Accuracy is  92.86213246967677

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.96      0.94      0.95     11484
#        Probe       0.96      0.61      0.74      2947
#          R2L       0.00      0.00      0.00       274
#          U2R       0.00      0.00      0.00        15
#       normal       0.91      1.00      0.95     16774
#
#     accuracy                           0.93     31494
#    macro avg       0.56      0.51      0.53     31494
# weighted avg       0.92      0.93      0.92     31494
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.1998158379373849
# Mean Squared Error -  0.6449164920302279
# Root Mean Squared Error -  0.8030669287364709
# R2 Score -  82.88055324849559
# Accuracy -  92.86213246967677

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=1.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=1.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Quadratic SVM Multi-class Classification")
plt.savefig('plots/qsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Multi-class Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train) # training model on training dataset
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
pkl_filename = "./models/knn_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=knn.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("KNN-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# KNN-Classifier Multi-class Set-Accuracy is  98.29173810884613

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.99      0.99      0.99     11484
#        Probe       0.96      0.97      0.96      2947
#          R2L       0.92      0.87      0.89       274
#          U2R       0.40      0.13      0.20        15
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.98     31494
#    macro avg       0.85      0.79      0.81     31494
# weighted avg       0.98      0.98      0.98     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.05086683177748143
# Mean Squared Error -  0.17285832222010541
# Root Mean Squared Error -  0.41576233862641454
# R2 Score -  95.23039034401897
# Accuracy -  98.29173810884613

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("KNN Multi Classification")
plt.savefig('plots/knn_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Linear Discriminant Analysis Classifier (Multi-class Classification)**

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train) # training model on training dataset
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
pkl_filename = "./models/lda_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lda = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = lda.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("LDA-Classifier Set-Accuracy is ", ac)
# Out:
# LDA-Classifier Set-Accuracy is  93.1923540991935

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.94      0.96      0.95     11484
#        Probe       0.88      0.73      0.80      2947
#          R2L       0.37      0.89      0.52       274
#          U2R       0.03      0.47      0.06        15
#       normal       0.97      0.95      0.96     16774
#
#     accuracy                           0.93     31494
#    macro avg       0.64      0.80      0.66     31494
# weighted avg       0.94      0.93      0.94     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.14380516923858513
# Mean Squared Error -  0.3957261700641392
# Root Mean Squared Error -  0.6290676991104687
# R2 Score -  89.08369120793829
# Accuracy -  93.1923540991935

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Linear Discriminant Analysis Multi-class Classification")
plt.savefig('plots/lda_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Quadratic Discriminant Analysis Classifier (Multi-class Classification)**

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train) # training model on training dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/discriminant_analysis.py:691: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
pkl_filename = "./models/qda_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qda, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qda = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = qda.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QDA-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# QDA-Classifier Multi-class Set-Accuracy is  44.98317139772655

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.99      0.42      0.59     11484
#        Probe       0.97      0.06      0.11      2947
#          R2L       0.03      1.00      0.06       274
#          U2R       0.00      0.00      0.00        15
#       normal       0.50      0.53      0.51     16774
#
#     accuracy                           0.45     31494
#    macro avg       0.50      0.40      0.26     31494
# weighted avg       0.72      0.45      0.50     31494
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  1.585190829999365
# Mean Squared Error -  5.0485806820346735
# Root Mean Squared Error -  2.246904689130065
# R2 Score -  -30.014570439814324
# Accuracy -  44.98317139772655

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Quadratic Discriminant Analysis Multi-class Classification")
plt.savefig('plots/qda_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93]  # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # initializing model
# input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with softmax activation
mlp.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 50)                4700
# _________________________________________________________________
# dense_50 (Dense)             (None, 5)                 255
# =================================================================
# Total params: 4,955
# Trainable params: 4,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 30ms/step - loss: 1.6137 - accuracy: 0.2266 - val_loss: 1.2707 - val_accuracy: 0.7465
# Epoch 2/100
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0614 - accuracy: 0.8222 - val_loss: 0.8303 - val_accuracy: 0.8683
# Epoch 3/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.7061 - accuracy: 0.8692 - val_loss: 0.5769 - val_accuracy: 0.8752
# Epoch 4/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.5178 - accuracy: 0.8732 - val_loss: 0.4547 - val_accuracy: 0.8772
# Epoch 5/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.4259 - accuracy: 0.8748 - val_loss: 0.3913 - val_accuracy: 0.8784
# Epoch 6/100
# 16/16 [==============================] - 0s 15ms/step - loss: 0.3731 - accuracy: 0.8797 - val_loss: 0.3497 - val_accuracy: 0.8897
# Epoch 7/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3355 - accuracy: 0.8898 - val_loss: 0.3177 - val_accuracy: 0.8949
# Epoch 8/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3051 - accuracy: 0.9012 - val_loss: 0.2913 - val_accuracy: 0.9205
# Epoch 9/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2798 - accuracy: 0.9261 - val_loss: 0.2689 - val_accuracy: 0.9333
# Epoch 10/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2584 - accuracy: 0.9351 - val_loss: 0.2504 - val_accuracy: 0.9383
# Epoch 11/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2411 - accuracy: 0.9393 - val_loss: 0.2354 - val_accuracy: 0.9413
# Epoch 12/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2270 - accuracy: 0.9406 - val_loss: 0.2228 - val_accuracy: 0.9414
# Epoch 13/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2152 - accuracy: 0.9438 - val_loss: 0.2121 - val_accuracy: 0.9472
# Epoch 14/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2052 - accuracy: 0.9482 - val_loss: 0.2030 - val_accuracy: 0.9485
# Epoch 15/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.
100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0998 - accuracy: 0.9671 - val_loss: 0.1014 - val_accuracy: 0.9663
# Epoch 77/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0994 - accuracy: 0.9676 - val_loss: 0.1008 - val_accuracy: 0.9662
# Epoch 78/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0989 - accuracy: 0.9677 - val_loss: 0.1006 - val_accuracy: 0.9673
# Epoch 79/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0985 - accuracy: 0.9681 - val_loss: 0.1000 - val_accuracy: 0.9670
# Epoch 80/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0981 - accuracy: 0.9678 - val_loss: 0.0996 - val_accuracy: 0.9672
# Epoch 81/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0976 - accuracy: 0.9683 - val_loss: 0.0994 - val_accuracy: 0.9671
# Epoch 82/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0972 - accuracy: 0.9680 - val_loss: 0.0989 - val_accuracy: 0.9671
# Epoch 83/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0968 - accuracy: 0.9680 - val_loss: 0.0985 - val_accuracy: 0.9675
# Epoch 84/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0964 - accuracy: 0.9682 - val_loss: 0.0982 - val_accuracy: 0.9676
# Epoch 85/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0960 - accuracy: 0.9684 - val_loss: 0.0978 - val_accuracy: 0.9675
# Epoch 86/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0957 - accuracy: 0.9687 - val_loss: 0.0974 - val_accuracy: 0.9681
# Epoch 87/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0953 - accuracy: 0.9687 - val_loss: 0.0972 - val_accuracy: 0.9679
# Epoch 88/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0950 - accuracy: 0.9689 - val_loss: 0.0967 - val_accuracy: 0.9680
# Epoch 89/100
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0946 - accuracy: 0.9690 - val_loss: 0.0965 - val_accuracy: 0.9684
# Epoch 90/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0943 - accuracy: 0.9694 - val_loss: 0.0963 - val_accuracy: 0.9688
# Epoch 91/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0940 - accuracy: 0.9696 - val_loss: 0.0958 - val_accuracy: 0.9684
# Epoch 92/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0936 - accuracy: 0.9693 - val_loss: 0.0955 - val_accuracy: 0.9686
# Epoch 93/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0933 - accuracy: 0.9694 - val_loss: 0.0953 - val_accuracy: 0.9684
# Epoch 94/100
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0930 - accuracy: 0.9696 - val_loss: 0.0950 - val_accuracy: 0.9687
# Epoch 95/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0927 - accuracy: 0.9696 - val_loss: 0.0946 - val_accuracy: 0.9686
# Epoch 96/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0924 - accuracy: 0.9695 - val_loss: 0.0944 - val_accuracy: 0.9687
# Epoch 97/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0920 - accuracy: 0.9698 - val_loss: 0.0941 - val_accuracy: 0.9686
# Epoch 98/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0918 - accuracy: 0.9699 - val_loss: 0.0939 - val_accuracy: 0.9689
# Epoch 99/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0915 - accuracy: 0.9701 - val_loss: 0.0936 - val_accuracy: 0.9691
# Epoch 100/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0912 - accuracy: 0.9700 - val_loss: 0.0935 - val_accuracy: 0.9688

# %%
filepath = './models/mlp_multi.json'
weightspath = './weights/mlp_multi.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")
  
  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.0935 - accuracy: 0.9689
# Test results - Loss: 0.0934750884771347 - Accuracy: 96.89464569091797%

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_multi_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/mlp_multi_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(mlp, to_file='plots/mlp_multi.png', show_shapes=True,)

# %%
n_classes = len(le2.classes_)
n_classes
# Out:
# 5

# %%
y_pred = mlp.predict(X_test)

# %%
fpr_mlp = dict()
tpr_mlp = dict()
roc_auc_mlp = dict()
for i in range(n_classes):
    fpr_mlp[i], tpr_mlp[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
    roc_auc_mlp[i] = auc(fpr_mlp[i], tpr_mlp[i])

# %%
for i in range(n_classes):
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_mlp[i], tpr_mlp[i], label='Keras (area = {:.3f})'.format(roc_auc_mlp[i]))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.savefig('plots/mlp_multi_roc'+str(i)+'.png')
  plt.show()

# %%
pred = mlp.predict(X_test)

# %%
for j in range(0,pred.shape[1]):
  for i in range(0,pred.shape[0]):
    pred[i][j] = int(round(pred[i][j]))

# %%
pred_df = pd.DataFrame(pred,columns=y_test.columns)

# %%
print("Recall Score - ",recall_score(y_test,pred_df.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,pred_df.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,pred_df.astype('uint8'),average='micro'))
# Out:
# Recall Score -  0.9691369784720899
# F1 Score -  0.9706780307848875
# Precision Score -  0.9722239918455756

# %% [markdown]
# # **Auto Encoder Classifier (Multi-class Classification)**

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test = train_test_split(multi_data, test_size=0.25, random_state=42)

# %%
# dataset excluding target attribute (encoded, one-hot-encoded,original)
y_train = X_train[['Dos','normal','Probe','R2L','U2R']]

X_train = X_train.drop(['intrusion','Dos','normal','Probe','R2L','U2R','label'],axis=1)

#y_test = X_test['intrusion'] # target attribute
y_test = X_test[['Dos','normal','Probe','R2L','U2R']]

# dataset excluding target attribute (encoded, one-hot-encoded,original)
X_test = X_test.drop(['intrusion','Dos','normal','Probe','R2L','U2R','label'],axis=1)

# %%
X = multi_data.iloc[:,0:93]  # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes

# %%
X_train = X_train.values
X_test = X_test.values
y_test = y_test.values

# %%
input_dim = X_train.shape[1]
encoding_dim = 50

#input layer
input_layer = Input(shape=(input_dim, ))
#encoding layer with 50 neurons
encoder = Dense(encoding_dim, activation="relu")(input_layer)           
#decoding and output layer
output_layer = Dense(input_dim, activation='softmax')(encoder)

# %%
# creating model with input, encoding, decoding, output layers
autoencoder = Model(inputs=input_layer, outputs=output_layer)

# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# summary of model layers
autoencoder.summary()
# Out:
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        [(None, 93)]              0
# _________________________________________________________________
# dense_51 (Dense)             (None, 50)                4700
# _________________________________________________________________
# dense_52 (Dense)             (None, 93)                4743
# =================================================================
# Total params: 9,443
# Trainable params: 9,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
history = autoencoder.fit(X_train, X_train, epochs=100,batch_size=500,validation_data=(X_test, X_test)).history
# Out:
# Epoch 1/100
# 189/189 [==============================] - 1s 5ms/step - loss: 0.1140 - accuracy: 0.4359 - val_loss: 0.1062 - val_accuracy: 0.6471
# Epoch 2/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1056 - accuracy: 0.6476 - val_loss: 0.1056 - val_accuracy: 0.6619
# Epoch 3/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1053 - accuracy: 0.7093 - val_loss: 0.1055 - val_accuracy: 0.7310
# Epoch 4/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1050 - accuracy: 0.7447 - val_loss: 0.1051 - val_accuracy: 0.7848
# Epoch 5/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1047 - accuracy: 0.7722 - val_loss: 0.1050 - val_accuracy: 0.7989
# Epoch 6/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1047 - accuracy: 0.7972 - val_loss: 0.1049 - val_accuracy: 0.8136
# Epoch 7/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1046 - accuracy: 0.8102 - val_loss: 0.1049 - val_accuracy: 0.8056
# Epoch 8/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1045 - accuracy: 0.8322 - val_loss: 0.1047 - val_accuracy: 0.8436
# Epoch 9/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8389 - val_loss: 0.1047 - val_accuracy: 0.8289
# Epoch 10/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8404 - val_loss: 0.1046 - val_accuracy: 0.8507
# Epoch 11/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8457 - val_loss: 0.1046 - val_accuracy: 0.8713
# Epoch 12/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8458 - val_loss: 0.1046 - val_accuracy: 0.8456
# Epoch 13/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8450 - val_loss: 0.1046 - val_accuracy: 0.8447
# Epoch 14/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8454 - val_loss: 0.1046 - val_accuracy: 0.8560
# Epoch 15/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8519 - val_loss: 0.1046 - val_accuracy: 0.8487
# Epoch 16/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8519 - val_loss: 0.1046 - val_accuracy: 0.8681
# Epoch 17/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8563 - val_loss: 0.1046 - val_accuracy: 0.8677
# Epoch 18/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8579 - val_loss: 0.1046 - val_accuracy: 0.8684
# Epoch 19/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8609 - val_loss: 0.1046 - val_accuracy: 0.8630
# Epoch 20/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1044 - accuracy: 0.8612 - val_loss: 0.1046 - val_accuracy: 0.8599
# Epoch 21/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8657 - val_loss: 0.1046 - val_accuracy: 0.8397
# Epoch 22/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8679 - val_loss: 0.1046 - val_accuracy: 0.8582
# Epoch 23/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8767 - val_loss: 0.1046 - val_accuracy: 0.8851
# Epoch 24/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8760 - val_loss: 0.1046 - val_accuracy: 0.8921
# Epoch 25/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8722 - val_loss: 0.1046 - val_accuracy: 0.8693
# Epoch 26/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8671 - val_loss: 0.1046 - val_accuracy: 0.8504
# Epoch 27/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8646 - val_loss: 0.1046 - val_accuracy: 0.8683
# Epoch 28/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8693 - val_loss: 0.1046 - val_accuracy: 0.9036
# Epoch 29/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8793 - val_loss: 0.1046 - val_accuracy: 0.8635
# Epoch 30/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8872 - val_loss: 0.1046 - val_accuracy: 0.8914
# Epoch 31/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8875 - val_loss: 0.1046 - val_accuracy: 0.8904
# Epoch 32/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8960 - val_loss: 0.1046 - val_accuracy: 0.8875
# Epoch 33/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8961 - val_loss: 0.1046 - val_accuracy: 0.9254
# Epoch 34/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8984 - val_loss: 0.1046 - val_accuracy: 0.9295
# Epoch 35/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8986 - val_loss: 0.1046 - val_accuracy: 0.9039
# Epoch 36/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.8995 - val_loss: 0.1046 - val_accuracy: 0.8789
# Epoch 37/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9012 - val_loss: 0.1046 - val_accuracy: 0.9020
# Epoch 38/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9015 - val_loss: 0.1046 - val_accuracy: 0.9358
# Epoch 39/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9036 - val_loss: 0.1046 - val_accuracy: 0.9039
# Epoch 40/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9044 - val_loss: 0.1046 - val_accuracy: 0.8973
# Epoch 41/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9052 - val_loss: 0.1046 - val_accuracy: 0.8801
# Epoch 42/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9066 - val_loss: 0.1046 - val_accuracy: 0.8932
# Epoch 43/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9063 - val_loss: 0.1046 - val_accuracy: 0.8920
# Epoch 44/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9060 - val_loss: 0.1046 - val_accuracy: 0.8801
# Epoch 45/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9086 - val_loss: 0.1046 - val_accuracy: 0.9312
# Epoch 46/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9073 - val_loss: 0.1046 - val_accuracy: 0.9025
# Epoch 47/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9101 - val_loss: 0.1046 - val_accuracy: 0.8935
# Epoch 48/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9110 - val_loss: 0.1046 - val_accuracy: 0.8982
# Epoch 49/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9108 - val_loss: 0.1046 - val_accuracy: 0.8430
# Epoch 50/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9104 - val_loss: 0.1046 - val_accuracy: 0.8914
# Epoch 51/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9099 - val_loss: 0.1046 - val_accuracy: 0.9300
# Epoch 52/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9112 - val_loss: 0.1046 - val_accuracy: 0.9353
# Epoch 53/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9118 - val_loss: 0.1046 - val_accuracy: 0.8742
# Epoch 54/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9127 - val_loss: 0.1046 - val_accuracy: 0.9024
# Epoch 55/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9125 - val_loss: 0.1046 - val_accuracy: 0.9279
# Epoch 56/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9110 - val_loss: 0.1046 - val_accuracy: 0.8928
# Epoch 57/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9130 - val_loss: 0.1046 - val_accuracy: 0.9310
# Epoch 58/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9134 - val_loss: 0.1046 - val_accuracy: 0.9387
# Epoch 59/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9131 - val_loss: 0.1046 - val_accuracy: 0.8750
# Epoch 60/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9154 - val_loss: 0.1046 - val_accuracy: 0.9233
# Epoch 61/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9153 - val_loss: 0.1046 - val_accuracy: 0.9001
# Epoch 62/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9165 - val_loss: 0.1046 - val_accuracy: 0.9190
# Epoch 63/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9165 - val_loss: 0.1046 - val_accuracy: 0.9033
# Epoch 64/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9141 - val_loss: 0.1046 - val_accuracy: 0.9442
# Epoch 65/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9157 - val_loss: 0.1046 - val_accuracy: 0.9342
# Epoch 66/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9175 - val_loss: 0.1046 - val_accuracy: 0.9191
# Epoch 67/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9160 - val_loss: 0.1046 - val_accuracy: 0.8909
# Epoch 68/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9158 - val_loss: 0.1046 - val_accuracy: 0.9265
# Epoch 69/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9177 - val_loss: 0.1046 - val_accuracy: 0.9454
# Epoch 70/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9175 - val_loss: 0.1046 - val_accuracy: 0.9088
# Epoch 71/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9179 - val_loss: 0.1046 - val_accuracy: 0.8932
# Epoch 72/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9170 - val_loss: 0.1046 - val_accuracy: 0.9160
# Epoch 73/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9183 - val_loss: 0.1046 - val_accuracy: 0.9144
# Epoch 74/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9188 - val_loss: 0.1046 - val_accuracy: 0.9258
# Epoch 75/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9174 - val_loss: 0.1046 - val_accuracy: 0.9229
# Epoch 76/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9188 - val_loss: 0.1046 - val_accuracy: 0.9558
# Epoch 77/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9191 - val_loss: 0.1046 - val_accuracy: 0.9320
# Epoch 78/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9187 - val_loss: 0.1046 - val_accuracy: 0.9247
# Epoch 79/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9185 - val_loss: 0.1046 - val_accuracy: 0.9476
# Epoch 80/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9196 - val_loss: 0.1046 - val_accuracy: 0.8830
# Epoch 81/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9195 - val_loss: 0.1046 - val_accuracy: 0.8960
# Epoch 82/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9193 - val_loss: 0.1046 - val_accuracy: 0.9233
# Epoch 83/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9183 - val_loss: 0.1046 - val_accuracy: 0.9340
# Epoch 84/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9196 - val_loss: 0.1046 - val_accuracy: 0.9374
# Epoch 85/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9200 - val_loss: 0.1046 - val_accuracy: 0.9094
# Epoch 86/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9187 - val_loss: 0.1046 - val_accuracy: 0.9057
# Epoch 87/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9195 - val_loss: 0.1046 - val_accuracy: 0.9282
# Epoch 88/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9201 - val_loss: 0.1046 - val_accuracy: 0.9249
# Epoch 89/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9198 - val_loss: 0.1046 - val_accuracy: 0.8926
# Epoch 90/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9208 - val_loss: 0.1046 - val_accuracy: 0.9086
# Epoch 91/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9201 - val_loss: 0.1046 - val_accuracy: 0.9246
# Epoch 92/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9199 - val_loss: 0.1046 - val_accuracy: 0.9530
# Epoch 93/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9207 - val_loss: 0.1046 - val_accuracy: 0.9108
# Epoch 94/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9202 - val_loss: 0.1046 - val_accuracy: 0.9385
# Epoch 95/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9211 - val_loss: 0.1046 - val_accuracy: 0.9227
# Epoch 96/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9213 - val_loss: 0.1046 - val_accuracy: 0.8905
# Epoch 97/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9201 - val_loss: 0.1046 - val_accuracy: 0.9119
# Epoch 98/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9211 - val_loss: 0.1046 - val_accuracy: 0.9351
# Epoch 99/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9219 - val_loss: 0.1046 - val_accuracy: 0.9230
# Epoch 100/100
# 189/189 [==============================] - 1s 4ms/step - loss: 0.1043 - accuracy: 0.9197 - val_loss: 0.1046 - val_accuracy: 0.9218

# %%
filepath = './models/ae_multi.json'
weightspath = './weights/ae_multi.h5'
if (not path.isfile(filepath)):  
  # serialize model to JSON
  autoencoder_json = autoencoder.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(autoencoder_json)

  # serialize weights to HDF5
  autoencoder.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  autoencoder = model_from_json(loaded_model_json)

  # load weights into new model
  autoencoder.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = autoencoder.evaluate(X_test, X_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.1046 - accuracy: 0.8897
# Test results - Loss: 0.10457070171833038 - Accuracy: 88.96615505218506%

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_multi_loss.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_multi_accuracy.png')
plt.show()

# %%
# representation of model layers
plot_model(autoencoder, to_file='plots/ae_multi.png', show_shapes=True,)

# %%
# calculating reconstruction error
predictions = autoencoder.predict(X_test)

# %% [markdown]
# ## **AE Classifier**

# %%
i_dim = predictions.shape[1]

#input layer
i_layer = Input(shape=(i_dim, ))
#hidden layer with 48 neurons
fvector = Dense(48, activation="sigmoid")(i_layer)   
#fvector = Dense(24, activation='tanh')(fvector)                 
#doutput layer
o_layer = Dense(5, activation='sigmoid')(fvector)

# %%
# creating model with input, encoding, decoding, output layers
ae_classifier = Model(inputs=i_layer, outputs=o_layer)

# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
ae_classifier.summary()
# Out:
# Model: "model_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        [(None, 93)]              0
# _________________________________________________________________
# dense_53 (Dense)             (None, 48)                4512
# _________________________________________________________________
# dense_54 (Dense)             (None, 5)                 245
# =================================================================
# Total params: 4,757
# Trainable params: 4,757
# Non-trainable params: 0
# _________________________________________________________________

# %%
# training the model on training dataset
his = ae_classifier.fit(predictions, y_test, epochs=200,batch_size=700, validation_split=0.2).history
# Out:
# Epoch 1/200
# 22/36 [=================>............] - ETA: 0s - loss: 0.1768 - accuracy: 0.4422
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f5be1fee0e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py", line 546, in __del__
#     handle=self._handle, deleter=self._deleter)
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1264, in delete_iterator
#     _ctx, "DeleteIterator", name, handle, deleter)
# KeyboardInterrupt:
# 36/36 [==============================] - 49s 1s/step - loss: 0.1644 - accuracy: 0.4765 - val_loss: 0.1363 - val_accuracy: 0.5321
# Epoch 2/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.5327 - val_loss: 0.1172 - val_accuracy: 0.5321
# Epoch 3/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.5327 - val_loss: 0.1080 - val_accuracy: 0.5321
# Epoch 4/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.5577 - val_loss: 0.1000 - val_accuracy: 0.8230
# Epoch 5/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.8238 - val_loss: 0.0916 - val_accuracy: 0.8343
# Epoch 6/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0876 - accuracy: 0.8338 - val_loss: 0.0827 - val_accuracy: 0.8381
# Epoch 7/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0789 - accuracy: 0.8371 - val_loss: 0.0743 - val_accuracy: 0.8379
# Epoch 8/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.8430 - val_loss: 0.0670 - val_accuracy: 0.8570
# Epoch 9/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.8577 - val_loss: 0.0612 - val_accuracy: 0.8570
# Epoch 10/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.8574 - val_loss: 0.0570 - val_accuracy: 0.8570
# Epoch 11/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.8574 - val_loss: 0.0539 - val_accuracy: 0.8571
# Epoch 12/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0533 - accuracy: 0.8574 - val_loss: 0.0517 - val_accuracy: 0.8573
# Epoch 13/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0514 - accuracy: 0.8576 - val_loss: 0.0500 - val_accuracy: 0.8573
# Epoch 14/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.8574 - val_loss: 0.0487 - val_accuracy: 0.8574
# Epoch 15/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 0.8576 - val_loss: 0.0477 - val_accuracy: 0.8574
# Epoch 16/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.8576 - val_loss: 0.0469 - val_accuracy: 0.8578
# Epoch 17/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.8574 - val_loss: 0.0463 - val_accuracy: 0.8578
# Epoch 18/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.8574 - val_loss: 0.0457 - val_accuracy: 0.8578
# Epoch 19/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.8574 - val_loss: 0.0451 - val_accuracy: 0.8570
# Epoch 20/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0456 - accuracy: 0.8573 - val_loss: 0.0447 - val_accuracy: 0.8570
# Epoch 21/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 0.8574 - val_loss: 0.0442 - val_accuracy: 0.8570
# Epoch 22/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 0.8574 - val_loss: 0.0438 - val_accuracy: 0.8573
# Epoch 23/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.8575 - val_loss: 0.0434 - val_accuracy: 0.8573
# Epoch 24/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0439 - accuracy: 0.8576 - val_loss: 0.0430 - val_accuracy: 0.8573
# Epoch 25/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 0.8575 - val_loss: 0.0426 - val_accuracy: 0.8574
# Epoch 26/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 0.8575 - val_loss: 0.0423 - val_accuracy: 0.8576
# Epoch 27/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.8576 - val_loss: 0.0419 - val_accuracy: 0.8576
# Epoch 28/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 0.8576 - val_loss: 0.0416 - val_accuracy: 0.8578
# Epoch 29/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.8579 - val_loss: 0.0412 - val_accuracy: 0.8578
# Epoch 30/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 0.8579 - val_loss: 0.0409 - val_accuracy: 0.8578
# Epoch 31/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.8579 - val_loss: 0.0405 - val_accuracy: 0.8576
# Epoch 32/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.8581 - val_loss: 0.0402 - val_accuracy: 0.8581
# Epoch 33/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0407 - accuracy: 0.8707 - val_loss: 0.0398 - val_accuracy: 0.8739
# Epoch 34/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 0.8733 - val_loss: 0.0395 - val_accuracy: 0.8743
# Epoch 35/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.8732 - val_loss: 0.0391 - val_accuracy: 0.8746
# Epoch 36/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.8733 - val_loss: 0.0387 - val_accuracy: 0.8746
# Epoch 37/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0393 - accuracy: 0.8730 - val_loss: 0.0383 - val_accuracy: 0.8746
# Epoch 38/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 0.8729 - val_loss: 0.0380 - val_accuracy: 0.8744
# Epoch 39/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.8729 - val_loss: 0.0376 - val_accuracy: 0.8746
# Epoch 40/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0383 - accuracy: 0.8811 - val_loss: 0.0373 - val_accuracy: 0.8752
# Epoch 41/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.8902 - val_loss: 0.0369 - val_accuracy: 0.8997
# Epoch 42/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.8976 - val_loss: 0.0366 - val_accuracy: 0.9006
# Epoch 43/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.8980 - val_loss: 0.0363 - val_accuracy: 0.9016
# Epoch 44/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.8981 - val_loss: 0.0360 - val_accuracy: 0.9017
# Epoch 45/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.8985 - val_loss: 0.0357 - val_accuracy: 0.9013
# Epoch 46/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.8986 - val_loss: 0.0355 - val_accuracy: 0.9017
# Epoch 47/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.8987 - val_loss: 0.0352 - val_accuracy: 0.9013
# Epoch 48/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 0.8986 - val_loss: 0.0350 - val_accuracy: 0.9011
# Epoch 49/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.8986 - val_loss: 0.0348 - val_accuracy: 0.9013
# Epoch 50/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0356 - accuracy: 0.8986 - val_loss: 0.0346 - val_accuracy: 0.9016
# Epoch 51/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 0.8987 - val_loss: 0.0344 - val_accuracy: 0.9020
# Epoch 52/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.8986 - val_loss: 0.0342 - val_accuracy: 0.9024
# Epoch 53/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.8987 - val_loss: 0.0341 - val_accuracy: 0.9020
# Epoch 54/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.8987 - val_loss: 0.0339 - val_accuracy: 0.9022
# Epoch 55/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.8988 - val_loss: 0.0338 - val_accuracy: 0.9025
# Epoch 56/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.8990 - val_loss: 0.0336 - val_accuracy: 0.9025
# Epoch 57/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 0.8993 - val_loss: 0.0335 - val_accuracy: 0.9028
# Epoch 58/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.8991 - val_loss: 0.0334 - val_accuracy: 0.9032
# Epoch 59/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.8995 - val_loss: 0.0333 - val_accuracy: 0.9033
# Epoch 60/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.8996 - val_loss: 0.0332 - val_accuracy: 0.9043
# Epoch 61/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.8997 - val_loss: 0.0331 - val_accuracy: 0.9046
# Epoch 62/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.8999 - val_loss: 0.0330 - val_accuracy: 0.9041
# Epoch 63/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.8998 - val_loss: 0.0329 - val_accuracy: 0.9046
# Epoch 64/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9001 - val_loss: 0.0328 - val_accuracy: 0.9046
# Epoch 65/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 0.9005 - val_loss: 0.0327 - val_accuracy: 0.9055
# Epoch 66/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0337 - accuracy: 0.9008 - val_loss: 0.0326 - val_accuracy: 0.9049
# Epoch 67/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9011 - val_loss: 0.0325 - val_accuracy: 0.9051
# Epoch 68/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9008 - val_loss: 0.0325 - val_accuracy: 0.9062
# Epoch 69/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9012 - val_loss: 0.0324 - val_accuracy: 0.9062
# Epoch 70/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9019 - val_loss: 0.0323 - val_accuracy: 0.9062
# Epoch 71/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9011 - val_loss: 0.0322 - val_accuracy: 0.9063
# Epoch 72/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9014 - val_loss: 0.0322 - val_accuracy: 0.9068
# Epoch 73/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9019 - val_loss: 0.0321 - val_accuracy: 0.9060
# Epoch 74/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9016 - val_loss: 0.0320 - val_accuracy: 0.9071
# Epoch 75/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9021 - val_loss: 0.0320 - val_accuracy: 0.9063
# Epoch 76/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9019 - val_loss: 0.0319 - val_accuracy: 0.9063
# Epoch 77/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9019 - val_loss: 0.0318 - val_accuracy: 0.9074
# Epoch 78/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9019 - val_loss: 0.0318 - val_accuracy: 0.9071
# Epoch 79/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9019 - val_loss: 0.0317 - val_accuracy: 0.9062
# Epoch 80/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9020 - val_loss: 0.0317 - val_accuracy: 0.9062
# Epoch 81/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9019 - val_loss: 0.0316 - val_accuracy: 0.9065
# Epoch 82/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9019 - val_loss: 0.0315 - val_accuracy: 0.9063
# Epoch 83/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 0.9021 - val_loss: 0.0315 - val_accuracy: 0.9063
# Epoch 84/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9021 - val_loss: 0.0314 - val_accuracy: 0.9070
# Epoch 85/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9022 - val_loss: 0.0314 - val_accuracy: 0.9070
# Epoch 86/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9023 - val_loss: 0.0313 - val_accuracy: 0.9070
# Epoch 87/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9029 - val_loss: 0.0313 - val_accuracy: 0.9098
# Epoch 88/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9048 - val_loss: 0.0312 - val_accuracy: 0.9105
# Epoch 89/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9049 - val_loss: 0.0312 - val_accuracy: 0.9105
# Epoch 90/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9055 - val_loss: 0.0312 - val_accuracy: 0.9103
# Epoch 91/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9056 - val_loss: 0.0311 - val_accuracy: 0.9103
# Epoch 92/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9057 - val_loss: 0.0311 - val_accuracy: 0.9106
# Epoch 93/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9057 - val_loss: 0.0310 - val_accuracy: 0.9113
# Epoch 94/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9057 - val_loss: 0.0310 - val_accuracy: 0.9106
# Epoch 95/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9056 - val_loss: 0.0309 - val_accuracy: 0.9114
# Epoch 96/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0322 - accuracy: 0.9054 - val_loss: 0.0309 - val_accuracy: 0.9113
# Epoch 97/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9056 - val_loss: 0.0308 - val_accuracy: 0.9116
# Epoch 98/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9058 - val_loss: 0.0308 - val_accuracy: 0.9111
# Epoch 99/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 0.9058 - val_loss: 0.0307 - val_accuracy: 0.9116
# Epoch 100/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9060 - val_loss: 0.0307 - val_accuracy: 0.9109
# Epoch 101/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9057 - val_loss: 0.0306 - val_accuracy: 0.9117
# Epoch 102/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9057 - val_loss: 0.0306 - val_accuracy: 0.9114
# Epoch 103/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0320 - accuracy: 0.9060 - val_loss: 0.0306 - val_accuracy: 0.9113
# Epoch 104/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9060 - val_loss: 0.0305 - val_accuracy: 0.9117
# Epoch 105/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9059 - val_loss: 0.0305 - val_accuracy: 0.9116
# Epoch 106/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 0.9059 - val_loss: 0.0305 - val_accuracy: 0.9109
# Epoch 107/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9061 - val_loss: 0.0304 - val_accuracy: 0.9111
# Epoch 108/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9060 - val_loss: 0.0304 - val_accuracy: 0.9117
# Epoch 109/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9061 - val_loss: 0.0304 - val_accuracy: 0.9111
# Epoch 110/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9061 - val_loss: 0.0303 - val_accuracy: 0.9125
# Epoch 111/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0317 - accuracy: 0.9064 - val_loss: 0.0303 - val_accuracy: 0.9114
# Epoch 112/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9061 - val_loss: 0.0302 - val_accuracy: 0.9124
# Epoch 113/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 0.9063 - val_loss: 0.0302 - val_accuracy: 0.9122
# Epoch 114/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9062 - val_loss: 0.0302 - val_accuracy: 0.9122
# Epoch 115/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9063 - val_loss: 0.0301 - val_accuracy: 0.9127
# Epoch 116/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9064 - val_loss: 0.0301 - val_accuracy: 0.9124
# Epoch 117/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9067 - val_loss: 0.0301 - val_accuracy: 0.9125
# Epoch 118/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9069 - val_loss: 0.0300 - val_accuracy: 0.9127
# Epoch 119/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9070 - val_loss: 0.0300 - val_accuracy: 0.9125
# Epoch 120/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9072 - val_loss: 0.0300 - val_accuracy: 0.9127
# Epoch 121/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9072 - val_loss: 0.0299 - val_accuracy: 0.9127
# Epoch 122/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0314 - accuracy: 0.9074 - val_loss: 0.0299 - val_accuracy: 0.9127
# Epoch 123/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9072 - val_loss: 0.0299 - val_accuracy: 0.9128
# Epoch 124/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9076 - val_loss: 0.0299 - val_accuracy: 0.9127
# Epoch 125/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9074 - val_loss: 0.0298 - val_accuracy: 0.9125
# Epoch 126/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9075 - val_loss: 0.0298 - val_accuracy: 0.9125
# Epoch 127/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9074 - val_loss: 0.0298 - val_accuracy: 0.9127
# Epoch 128/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9077 - val_loss: 0.0297 - val_accuracy: 0.9127
# Epoch 129/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9076 - val_loss: 0.0297 - val_accuracy: 0.9125
# Epoch 130/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 0.9079 - val_loss: 0.0297 - val_accuracy: 0.9127
# Epoch 131/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9077 - val_loss: 0.0297 - val_accuracy: 0.9127
# Epoch 132/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9078 - val_loss: 0.0296 - val_accuracy: 0.9130
# Epoch 133/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9075 - val_loss: 0.0296 - val_accuracy: 0.9135
# Epoch 134/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9079 - val_loss: 0.0296 - val_accuracy: 0.9132
# Epoch 135/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9078 - val_loss: 0.0296 - val_accuracy: 0.9128
# Epoch 136/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9080 - val_loss: 0.0295 - val_accuracy: 0.9132
# Epoch 137/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9079 - val_loss: 0.0295 - val_accuracy: 0.9136
# Epoch 138/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9081 - val_loss: 0.0295 - val_accuracy: 0.9140
# Epoch 139/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9081 - val_loss: 0.0295 - val_accuracy: 0.9138
# Epoch 140/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9085 - val_loss: 0.0295 - val_accuracy: 0.9128
# Epoch 141/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9083 - val_loss: 0.0295 - val_accuracy: 0.9135
# Epoch 142/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9083 - val_loss: 0.0294 - val_accuracy: 0.9144
# Epoch 143/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9086 - val_loss: 0.0294 - val_accuracy: 0.9138
# Epoch 144/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9087 - val_loss: 0.0294 - val_accuracy: 0.9146
# Epoch 145/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9087 - val_loss: 0.0294 - val_accuracy: 0.9144
# Epoch 146/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9086 - val_loss: 0.0293 - val_accuracy: 0.9147
# Epoch 147/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9087 - val_loss: 0.0293 - val_accuracy: 0.9144
# Epoch 148/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9088 - val_loss: 0.0293 - val_accuracy: 0.9149
# Epoch 149/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 0.9089 - val_loss: 0.0293 - val_accuracy: 0.9147
# Epoch 150/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9090 - val_loss: 0.0293 - val_accuracy: 0.9151
# Epoch 151/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9089 - val_loss: 0.0293 - val_accuracy: 0.9146
# Epoch 152/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9088 - val_loss: 0.0293 - val_accuracy: 0.9149
# Epoch 153/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9091 - val_loss: 0.0292 - val_accuracy: 0.9147
# Epoch 154/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9089 - val_loss: 0.0292 - val_accuracy: 0.9149
# Epoch 155/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9091 - val_loss: 0.0292 - val_accuracy: 0.9152
# Epoch 156/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9091 - val_loss: 0.0292 - val_accuracy: 0.9154
# Epoch 157/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9092 - val_loss: 0.0292 - val_accuracy: 0.9149
# Epoch 158/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9093 - val_loss: 0.0291 - val_accuracy: 0.9154
# Epoch 159/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9094 - val_loss: 0.0291 - val_accuracy: 0.9149
# Epoch 160/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9092 - val_loss: 0.0291 - val_accuracy: 0.9154
# Epoch 161/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9095 - val_loss: 0.0291 - val_accuracy: 0.9151
# Epoch 162/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9094 - val_loss: 0.0291 - val_accuracy: 0.9149
# Epoch 163/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9094 - val_loss: 0.0291 - val_accuracy: 0.9154
# Epoch 164/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9095 - val_loss: 0.0290 - val_accuracy: 0.9155
# Epoch 165/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9097 - val_loss: 0.0290 - val_accuracy: 0.9154
# Epoch 166/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9095 - val_loss: 0.0290 - val_accuracy: 0.9159
# Epoch 167/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9097 - val_loss: 0.0290 - val_accuracy: 0.9152
# Epoch 168/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9096 - val_loss: 0.0290 - val_accuracy: 0.9159
# Epoch 169/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9098 - val_loss: 0.0290 - val_accuracy: 0.9159
# Epoch 170/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 0.9100 - val_loss: 0.0290 - val_accuracy: 0.9159
# Epoch 171/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9098 - val_loss: 0.0289 - val_accuracy: 0.9159
# Epoch 172/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9101 - val_loss: 0.0289 - val_accuracy: 0.9160
# Epoch 173/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 0.9101 - val_loss: 0.0290 - val_accuracy: 0.9159
# Epoch 174/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9100 - val_loss: 0.0289 - val_accuracy: 0.9162
# Epoch 175/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9099 - val_loss: 0.0289 - val_accuracy: 0.9157
# Epoch 176/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9100 - val_loss: 0.0289 - val_accuracy: 0.9160
# Epoch 177/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9104 - val_loss: 0.0289 - val_accuracy: 0.9159
# Epoch 178/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9103 - val_loss: 0.0288 - val_accuracy: 0.9163
# Epoch 179/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9103 - val_loss: 0.0288 - val_accuracy: 0.9160
# Epoch 180/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9105 - val_loss: 0.0288 - val_accuracy: 0.9160
# Epoch 181/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9105 - val_loss: 0.0288 - val_accuracy: 0.9162
# Epoch 182/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9105 - val_loss: 0.0288 - val_accuracy: 0.9163
# Epoch 183/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9106 - val_loss: 0.0288 - val_accuracy: 0.9162
# Epoch 184/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9103 - val_loss: 0.0288 - val_accuracy: 0.9163
# Epoch 185/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9106 - val_loss: 0.0288 - val_accuracy: 0.9163
# Epoch 186/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9106 - val_loss: 0.0287 - val_accuracy: 0.9162
# Epoch 187/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9103 - val_loss: 0.0287 - val_accuracy: 0.9162
# Epoch 188/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9106 - val_loss: 0.0287 - val_accuracy: 0.9167
# Epoch 189/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9111 - val_loss: 0.0287 - val_accuracy: 0.9160
# Epoch 190/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 0.9107 - val_loss: 0.0287 - val_accuracy: 0.9163
# Epoch 191/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9106 - val_loss: 0.0287 - val_accuracy: 0.9168
# Epoch 192/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9112 - val_loss: 0.0286 - val_accuracy: 0.9162
# Epoch 193/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9108 - val_loss: 0.0286 - val_accuracy: 0.9163
# Epoch 194/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9107 - val_loss: 0.0286 - val_accuracy: 0.9162
# Epoch 195/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9111 - val_loss: 0.0286 - val_accuracy: 0.9167
# Epoch 196/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9107 - val_loss: 0.0286 - val_accuracy: 0.9163
# Epoch 197/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9109 - val_loss: 0.0286 - val_accuracy: 0.9165
# Epoch 198/200
# 36/36 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9111 - val_loss: 0.0285 - val_accuracy: 0.9163
# Epoch 199/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9109 - val_loss: 0.0285 - val_accuracy: 0.9167
# Epoch 200/200
# 36/36 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9107 - val_loss: 0.0285 - val_accuracy: 0.9165

# %%
filepath = './models/ae_classifier_multi.json'
weightspath = './weights/ae_classifier_multi.h5'
if (not path.isfile(filepath)): 
  # serialize model to JSON
  ae_classifier_json = ae_classifier.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(ae_classifier_json)

  # serialize weights to HDF5
  ae_classifier.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  ae_classifier = model_from_json(loaded_model_json)

  # load weights into new model
  ae_classifier.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
ae_classifier.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
test_results = ae_classifier.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 1s 1ms/step - loss: 0.0745 - accuracy: 0.8420
# Test results - Loss: 0.07446259260177612 - Accuracy: 84.20016765594482%

# %%
# representation of model layers
plot_model(ae_classifier, to_file='plots/ae_classifier_multi.png', show_shapes=True)

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(his['loss'])
plt.plot(his['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/ae_classifier_multi_loss.png')
plt.show()

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(his['accuracy'])
plt.plot(his['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/ae_classifier_multi_accuracy.png')
plt.show()

# %%
y_pred = ae_classifier.predict(X_test)

# %%
fpr_ae = dict()
tpr_ae = dict()
roc_auc_ae = dict()
for i in range(n_classes):
    fpr_ae[i], tpr_ae[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc_ae[i] = auc(fpr_ae[i], tpr_ae[i])

# %%
for i in range(n_classes):
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_ae[i], tpr_ae[i], label='Keras (area = {:.3f})'.format(roc_auc_ae[i]))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.savefig('plots/ae_classifier_multi_roc'+str(i)+'.png')
  plt.show()

# %%
for j in range(0,y_pred.shape[1]):
  for i in range(0,y_pred.shape[0]):
    y_pred[i][j] = int(round(y_pred[i][j]))

# %%
print("Recall Score - ",recall_score(y_test,y_pred.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,y_pred.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,y_pred.astype('uint8'),average='micro'))
# Out:
# Recall Score -  0.8688639105861434
# F1 Score -  0.8001052616189821
# Precision Score -  0.7414311648196819
